# %%
import os
import requests
from json import loads
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
def download_img():
    with requests.get(file_url, stream=True, headers=headers) as r:
        r.raise_for_status()
        with open("attachments/{}.{}".format(stamp, fmt), 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36',
}

# %%
with open('face_detection.json', 'rb') as f:
    to_download = []
    for l in f.readlines():
        to_download.append(loads(l))

# %%
datas = np.load('/home/alfarihfz/Datasets/face_keypoints/face_images.npz')['face_images']

# %%
cv2.imshow('test', datas['face_images'][:,:,0])
cv2.waitKey()
# Out:
# 32

# %%
cv2.imwrite('img.jpg', datas[:,:,100])
# Out:
# True

# %%
import pandas as pd
import numpy as np
import os

# %%
test = pd.read_csv('/home/alfarihfz/Datasets/face_keypoints/face_images.csv')

# %%
files = os.listdir('Datasets/JPEGImages')

# %%
annos = os.listdir('Datasets/Annotations')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(files, annos, shuffle=True, test_size=0.2)

# %%
X_train = [y.split('.xml')[0] for y in Y_train]

# %%
X_test = [y.split('.xml')[0] for y in Y_test]

# %%
with open('train.txt', 'w') as f:
    for y in X_train:
        f.writelines("%s\n"%y)

# %%
with open('test.txt', 'w') as f:
    for y in X_test:
        f.writelines("%s\n"%y)

# %%
X_train
# Out:
# ['17dac3af-a1fb-46f7-b4f8-4882185b6d38___thequint2F2017-122F72a62cb9-f80f-4dc8-926d-8a74e8cf39822Fnon20english20movies.jpg.jpeg',
#  '39e6eb3f-9409-4d7d-ae1d-5a56f611c166___Master.jpg.jpeg',
#  'ae1e3cee-1b64-4415-9cc2-f218ec8cb113___articles_fartsinmovies.jpg.jpeg',
#  '427551d7-e049-470c-abd6-c036b2cd3493___sometimes-mimicking-scenes-from-movies-will-cost-you-x-gifs-288.jpg.jpeg',
#  '653a7c6a-a200-4b7c-9e4d-1f873ccb14a0___128296_v1.jpg.jpeg',
#  '40c39921-79bd-4200-8ad5-518762d63ccb___hqdefault5.jpg.jpeg',
#  '73f9b5b7-0455-4033-bf52-6c5cc9b52ecd___825a26941df80f8fdb3569ed6c1ee999.jpg.jpeg',
#  'ef358b9f-6c05-451e-b327-8f1c91ec86c9___jumanji-et00041704-04-10-2016-03-57-35.jpg.jpeg',
#  '8c86556e-fd21-4dd9-87dd-d4ace99a34bf___oz.jpg.jpeg',
#  '6c110535-9d3d-48d2-8025-d16847b37a95___multi-generational-asian-family.jpg.jpeg',
#  '592b7b5d-a87e-442e-8054-611950f3ef50___GettyImages-973687124-640x480.jpg.jpeg',
# ...
