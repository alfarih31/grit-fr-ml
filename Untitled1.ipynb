# %%
import os

# %%
real = os.listdir("Datasets/real")

# %%
with open('real.txt', 'w') as f:
    for r in real:
        f.writelines("%s\n"%r.strip())

# %%
real = os.listdir("Datasets/image_in_image")
with open('image_in_image.txt', 'w') as f:
    for r in real:
        f.writelines("%s\n"%r.strip())

# %%
len(real)
# Out:
# 200
